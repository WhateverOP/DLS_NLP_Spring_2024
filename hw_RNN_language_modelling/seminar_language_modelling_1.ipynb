# %% [markdown]
# # Обучение char-level языковой модели с помощью RNN

# %% [markdown]
# Установим модуль datasets, чтобы нам проще было работать с данными

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 7.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1

# %% [markdown]
# Импорт необходимых библиотек

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import numpy as np
import matplotlib.pyplot as plt

from tqdm.auto import tqdm
from datasets import load_dataset
from nltk.tokenize import sent_tokenize
from sklearn.model_selection import train_test_split
import nltk

from collections import Counter
from typing import List

import seaborn
seaborn.set(palette='summer')

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ## Подготовка данных

# %%
# Загрузим датасет
dataset = load_dataset('IlyaGusev/gazeta', revision="v1.0")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1461: FutureWarning: The repository for IlyaGusev/gazeta contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/IlyaGusev/gazeta
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.98k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/3.87k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/12.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/48.6M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/52.1M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/52400 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5770 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5265 [00:00<?, ? examples/s]

# %%
sentences = []

for sentence in tqdm(dataset['validation']['text']):
    sentences.extend(
        [x.lower() for x in sent_tokenize(sentence, language='russian') if len(x) < 128]
        )
# Out:
#   0%|          | 0/5265 [00:00<?, ?it/s]

# %%
sentences[1500]
# Out:
# 'сразу после этого климкин обратился к парламентариям с просьбой все-таки отправить его в отставку.'

# %%
len(sentences)
# Out:
# 122237

# %%
sentences
# Out:
# ['красно-белые, усилив атакующую линию, взялись за укрепление центральной зоны.',
#  'особенно актуальным данный вопрос стал после ухода бразильского хавбека фернадо в китайский «бэйцзин гоань».',
#  'nejvyssi vedeni ruskeho klubu navstivilo v minulych dnech ceskou republiku.',
#  'ani jeden nyni neni na prodej.',
#  'кроме спортивного директора москвичей томаса цорна.',
#  'позднее же французские журналисты назвали другого возможного новичка москвичей, а именно опорника «ниццы» адриена тамеза.',
#  'именно при знаменитом в прошлом футболисте тамез закрепился в основном составе «орлов».',
#  'учитывая это, со своим ключевым игроком «ницца» и виейра в частности не торопятся.',
#  'свою профессиональную карьеру французский полузащитник начал в «нанси», выпускником клубной академии которого он и является.',
#  'однако по окончании сезона-2017/18 фавр был вынужден покинуть «ниццу», возглавив впоследствии дортмундскую «боруссию».',
#  'по системе гол+пас француз набрал шесть баллов.',
#  'для самого же адриена возможный переезд в москву не станет первым визитом столицы россии.',
#  'что касается характеристик тамеза, то хавбек может стать отличной заменой фернандо.',
#  'единственное, в чем, пожалуй, потенциальный новичок «спартака» проигрывает своему предшественнику, — это качество передач.',
#  'причем как дальних, так и ближних.',
#  'в чемпионате россии фернандо по данному компоненту был одним из лучших, тамеза же на данные лавры вряд ли сможет претендовать.',
#  'в 4 из 5 случаев француз предпочтет пойти в дриблинг, нежели сделать передачу, что может сыграть с красно-белыми злую шутку.',
#  'в настоящее время российские разработчики еще создают летательный аппарат.',
#  'автор обратил внимание, что это «фундаментально новый бомбардировщик, созданный на основе современных решений».',
#  'в то время как ранее оружие создавалось на основе советских проектов.',
#  '«самый поразительный аспект пак-да — это то, насколько он близок к поступлению на вооружение.',
#  'автор предположил, что эти заряды будут храниться «во внутреннем оружейном отсеке пак да».',
#  'тогда же он заявил о том, что планируется создать средний военно-транспортный самолет, передает риа «новости».',
#  'в планах также — создание и запуск до конца года линейной станции обслуживания самолетов ту-204 и ту-214», — рассказал конюхов.',
#  'в конце января 2019 года конюхов сообщил, что разработка пак да займет меньше 10 лет.',
#  '«на создание «изделия-80» [заводское обозначение пак да] заложено  пять-семь лет», — приводит его слова телеканал «звезда».',
#  'между тем о начале разработки этого летательного аппарата стало известно осенью прошлого года.',
#  'соответствующее заявление было опубликовано в фейсбуке объединенной авиастроительной корпорации.',
#  '«с какой стати?',
#  'если вам все понятно, зачем еще раз гонять людей на какое-то голосование?',
#  'надеюсь, джон [керри] на меня не обидится», — сказал лавров в интервью принадлежащему григорию березкину рбк.',
#  'украина и большинство западных стран итогов плебисцита не признают.',
#  'летом 2018 года трамп возложил вину за ситуацию вокруг крыма на своего предшественника барака обаму.',
#  'но в отношении москвы «за крым» продолжат действовать.',
#  '«скорее, важны санкции, связанные с донбассом, и санкции, связанные с американскими выборами.',
#  'они куда больше связывают руки и ограничивают возможности ведения бизнеса в россии», — сказал бизнесмен в интервью «газете.ru».',
#  'недавно евросоюз одобрил продление санкций в отношении крыма и севастополя, сообщает тасс со ссылкой на bloomberg.',
#  'по данным агентства, ес намерен продлить антироссийские санкции по крыму до 23 июня 2020 года.',
#  'решение будет принято 18-20 июня.',
#  '«с каждым годом крым становится все более самодостаточным субъектом», — подчеркнул полонский.',
#  'он отметил, что когда-нибудь евросоюз убедится в том, что санкции не приносят желаемого результата.',
#  'в марте 2019 года европейский союз включил восемь высокопоставленных военных россии в свой санкционный список.',
#  'в настоящее время украинские военнослужащие находятся в предварительном заключении, в их отношении идут следственные действия.',
#  'мид рф в ответ сообщил о расширении списка тех, кому запрещен въезд на территорию российской федерации.',
#  'в документе говорится о ввозе товаров из-за рубежа для личного пользования.',
#  'с 1 января 2019 года порог беспошлинного ввоза иностранных посылок в россию был снижен с €1 тыс. до €500.',
#  'в результате налог составит 15% от суммы превышения, но не менее €2 за 1 кг сверх лимита.',
#  'как прокомментировали «газете.ru» в минфине, «речь не идет о введении какого-либо нового вида сборов».',
#  'но это далеко не обязательно приведет к росту покупок на российских интернет-площадках, говорит он.',
#  '«с одной стороны, не все глупые высказывания американских генералов нужно комментировать.',
#  'дипломат назвала совершенно безответственными подобные выпады, наносящий ощутимый вред имиджу самого вашингтона.',
#  'там также добавили, что пилоты надо в курсе возможностей про этого региона.',
#  'харригэн выступил со своим резонансным заявлением накануне.',
#  'по его словам, сша отрабатывают необходимые маневры для реализации подобного плана.',
#  'однако он не привел никаких деталей планов сша по обходу российских средств противовоздушной обороны.',
#  'еще одна атака была осуществлена на второе по величине нефтяное месторождение страны хураис.',
#  'хуситы заявили, что проведенная атака стала ответом на деструктивные действия властей саудовской аравии.',
#  'эсминцы вмс сша оснащены системой противоракетной обороны aegis и имеют на вооружении 100 ракет модификации sm-2.',
#  '«в течение двух лет подводная лодка и сами беспилотники «посейдон» будут проходить совместные испытания.',
#  '«белгород» станет самой крупной подводной лодкой в составе вмф.',
#  'остальные характеристики апл держатся в строгой секретности.',
#  '«белгород» привлек особенно пристальное внимание запада и получила оттуда достаточно лестные отзывы.',
#  'британский таблоид the sun окрестил ее «морским монстром».',
#  'к-329 «белгород» проекта 09852 создается на базе недостроенной атомной подводной лодки с крылатыми ракетами проекта 949ам.',
#  'на последней будет обычная, а не воздухонезависимая энергетическая установка.',
#  'к сожалению, в россии пока нет дизель-электрических подводных лодок с воздухонезависимой энергетической установкой.',
#  'ранее утверждалось, что первые внэу получат субмарины проекта 677 «лада».',
#  'и только следующая субмарина этого проекта получит внэу.',
#  'спустить на воду ее предполагается до 2025 года.',
#  'появление внэу на отечественных дэпл резко улучшит их конкурентные преимущества в сравнении с западными аналогами.',
#  'в сочетании с ракетным комплексом «калибр» это будет поистине грозное оружие.',
#  'таким образом там ответили на просьбу прокомментировать информацию источника агентства.',
#  'планируется, что до конца этого года вмф получит две подлодки.',
#  'министр обороны рф сергей шойгу ранее отмечал, что до конца года флоту передадут три подлодки: одну дизельную и две атомные.',
#  'по данным газеты, плур находится в высокой степени готовности.',
#  'она предназначена для уничтожения вражеских субмарин на расстояниях в десятки километров, указали в статье.',
#  'наводиться оружие будет с помощью патрульного самолета или вертолета.',
#  'сама плур будет расположена в универсальном транспортно-пусковом контейнере (тпк), рассказали в издании.',
#  'по информации журналистов, конструктивно ракета напоминает матрешку с малогабаритной торпедой в головной части.',
#  'попав в заданный район, оружие отделяется от носителя, а затем самостоятельно находит и поражает вражескую субмарину.',
#  '«гарантия уничтожения вражеской подводной лодки этим видом оружия превышает 90%.',
#  'так, нехватку россиянок испытают ленинградская область, где на тысячу мужчин через 17 лет будет 914 женщин.',
#  'хотя сейчас там этот показатель равен 1114.',
#  'в севастополе также будет уменьшение количества женщин по отношению к тысяче мужчин.',
#  'в то время как сейчас там женщин больше, чем мужчин на 119, 91, 69 человек соответственно.',
#  'росстат предполагает, что с 2031 года мужчин станет чуть больше, чем женщин, и на камчатке.',
#  'специалисты статистической службы связывают это с более высокими рисками смертности мужчин.',
#  'так, на начало этого года специалисты насчитали 20 582 долгожителя.',
#  'по сравнению с 2017 годом этот показатель вырос на 17%.',
#  '«все больше людей пожилого возраста оперируется или им оказывается самая современная помощь без оглядки на возраст.',
#  'улучшаются технологии анестезии, хирургические технологии, диагностики.',
#  'они становятся эффективными и безопасными даже для людей пожилого возраста», — сказала врач радиостанции «говорит москва».',
#  'при этом более 70% россиян в возрасте 100 лет и старше – женщины.',
#  'это, по словам гериатра, соответствует мировой тенденции.',
#  'есть и другие биологические факторы, но они продолжают изучаться даже на уровне генетики», — отметила ткачева.',
#  'жительница москвы алена хованова заявила, что ее избили участники команды американской певицы дженнифер лопес.',
#  'девушка только сейчас решилась обнародовать конфликт, произошедший в минувшие выходные в одном из отелей санкт-петербурга.',
#  'поп-звезда посетила северную столицу в рамках гастрольного тура.',
#  'ее команда заселилась в гостиницу, в которой остановилась пострадавшая москвичка.',
#  '«весь первый этаж был заполнен этими людьми, а сам ресепшен отеля находился на втором этаже, что затрудняло любое передвижение.',
#  'мы спросили, можем ли как-то подняться к своему номеру, однако нам ответили в грубой форме», — сказала девушка.',
#  'в распоряжении рен тв оказалось видео с камер наблюдения, на котором видно, как хованова ожидает лифт.',
#  'через некоторое время к ней приближается мужчина из коллектива знаменитости и начинает говорить с ней в агрессивной форме.',
#  'в конечном счете дело дошло до рукоприкладства.',
#  '«смех разразился еще больше и я ощутила на себе удар по лицу.',
#  'по ее словам, возврат средств они получили не сразу.',
#  'вероятно, девушка не догадалась сразу вызвать полицию, а в отеле, по ее словам, охрана отсутствовала.',
#  'теперь, оправившись от шока, пострадавшая намерена обратиться в правоохранительные органы и добиться сатисфакции.',
#  'корреспондент «мк» дозвонился в отель, где произошел инцидент.',
#  'на вопрос о произошедшем, сотрудник заведения лаконично заявил, что не станет комментировать ситуацию.',
#  '«вечеринка» звезды была приурочена к празднованию ее 50-летия, которое она отметила 24 июля.',
#  '«прихожу в форму перед репетициями.',
#  'время тура почти пришло», — написала певица.',
#  'согласно информации прессы, лопес также приводит себя в форму перед свадьбой со своим возлюбленным?',
#  'бейсболистом алексом родригесом , с которым они помолвились в марте.',
#  'известно, что спортсмен подарил своей невесте кольцо за $4,5 млн.',
#  'в министерстве финансов сообщили детали законопроекта о новой системе добровольных пенсионных накоплений.',
#  'документ уже направлен на согласование в минтруд.',
#  'как отмечается, один из основных элементов «гарантированного пенсионного продукта» — добровольность вступления.',
#  'помимо этого, государство обещает сохранность долгосрочных пенсионных накоплений.',
#  'для бизнеса предполагается ввести налоговые льготы, а для граждан — налоговые вычеты.',
#  'при этом накопительные счета граждан должны регистрироваться центральным администратором.',
#  'чиновник не исключал, что это будет во время московского финансового форума, который пройдет 12-13 сентября.',
#  'при этом он говорил, что названия ипк (индивидуального пенсионного напитала) не будет.',
#  '«основная история — будет отказ от любых средств принуждения к вступлению граждан (в систему)», — сказал он журналистам.',
#  'для граждан накопительный компонент был пересчитан в пенсионные коэффициенты.',
#  'концепция ипк была разработана еще в 2016.',
#  'однако чиновники так и не смогли прийти к единому мнению, и разгорелись ожесточенные споры.',
#  'ключевым моментом оказался так называемый пункт об «автоподписке».',
#  'но социальному блоку правительства это не понравилось.',
#  'в результате дискуссий в правительстве и среди экспертов от нового способа решено было отказаться.',
#  'при этом, как указывали ряд экспертов, проект также завис из-за того, что на первое место вышла пенсионная реформа.',
#  'между тем ранее чиновники называли 2020 год как срок, в который вполне возможно запустить ипк.',
#  'в любом случае эксперты считают, что новая система накопления вряд ли вызовет интерес у россиян.',
#  'согласно источнику, в обнародованном письме 37-летняя поп-звезда преимущественно говорит о себе в третьем лице.',
#  'то, что случилось с бритни, произошло год назад.',
#  'адвокаты заставили бритни развестись с ним, так как были уверены, что — если бритни не подаст на развод — он сам сделает это.',
#  'кевин пытается сыграть роль невинной жертвы.',
#  'но он сам оставил бритни и ее детей», — утверждает в письме спирс.',
#  'артистка, однако, отказалась выдать младшего сына, заперевшись с ним в ванной, в результате чего на место была вызвана полиция.',
#  'прибывшие в дом певицы правоохранители позднее утверждали, что спирс находилась «под воздействием неизвестного вещества».',
#  'в итоге бритни, которой тогда было 26 лет, была насильно отправлена в больницу на лечение.',
#  '— бритни обманули и подставили.',
#  'ее детей забрали, и она действительно вышла из-под контроля, что сделала бы любая мать в таких обстоятельствах».',
#  '— бритни дала брату $2 млн, у ее матери есть поместье стоимостью в $4 млн, а ее отец имеет лучшую работу в шоу-бизнесе.',
#  'бритни — очень щедрый человек.',
#  'и она хотела бы получить уважение, которое заслуживает».',
#  'несколько недель назад в сми, напомним, появилась информация, что спирс снова находится на грани нервного срыва.',
#  'беспокойство относительно психического здоровья поп-звезды высказали члены ее семьи.',
#  'по их мнению, лечение в психиатрической больнице, которое в свое время прошла артистка, дало лишь кратковременный результат.',
#  '«бритни страдает от изнурительных эмоциональных проблем, которые нужно лечить лекарствами.',
#  'такое ощущение, будто она сейчас не контролирует свои эмоции.',
#  'все очень нестабильно», — рассказал изданию people родственник бритни.',
#  'источник также сообщил, что пройденная бритни терапия с течением времени якобы утратила свою эффективность.',
#  'верховный лидер ирана аятолла али хаменеи заявил, что тегеран не будет вести переговоры с вашингтоном ни на каком уровне.',
#  'речь идет о документе, который был согласован еще в 2015 году.',
#  'свпд предусматривал постановку ядерной программы ирана под контроль магатэ в обмен на снятие санкций.',
#  'по его словам, иран якобы несет ответственность за данный инцидент.',
#  '«сша не хотят ни с кем войны.',
#  'у нас лучшее оружие в мире, мы потратили за последнее время $1,5 трлн.',
#  'у нас лучшее оборудование, ракеты, истребители ни с кем не хотим войны, но мы лучше подготовлены.',
#  'однако, как я сказал, мы хотим избежать этого», — добавил трамп.',
#  '«я знаю, что он хочет встретиться, но, как страна, они не очень хорошо себя ведут.',
#  'условия [для встречи] всегда есть, санкции не могут быть сняты.',
#  'санкции — это условие.',
#  'посмотрим, что произойдет, учитывая эти атаки», — подчеркнул трамп.',
#  'десять беспилотников атаковали саудовские нефтяные объекты, принадлежащие госкомпании saudi aramco, ночью 14 сентября.',
#  'ответственность за нападение взяли на себя йеменские повстанцы-хуситы.',
#  'однако сша считают, что за инцидентом якобы стоит иран. в свою очередь, тегеран не раз отвергал обвинения вашингтона.',
#  'сша проводят политику максимального давления в отношении ирана с момента выхода из иранской ядерной сделки.',
#  'при этом трамп неоднократно заявлял, что власти тегерана хотят переговоров с сша.',
#  'однако иран не собирается что-либо обсуждать с вашингтоном без снятия санкций.',
#  'он также добавил, что билетом на переговоры является возвращение сша к ядерной сделке.',
#  'по мнению экспертов, это должно было привести к улучшению в отношениях между вашингтоном и тегераном.',
#  'ряд сми также утверждал, что увольнение болтона связано с желанием трампа смягчить санкции в отношении ирана.',
#  'дэррок оказался в центре скандала после того, как его письма для британского мида попали в сми.',
#  'при этом на уход дэррока в отставку из-за скандала с трампом отреагировали в лондоне.',
#  'по словам премьер-министра великобритании терезы мэй, она обсудила с послом его решение.',
#  '«я выразила ему огромное сожаление, что он посчитал необходимым оставить свой пост посла в вашингтоне.',
#  'сэр ким посвятил всю свою жизнь служению соединенному королевству», — заявила премьер в британском парламенте.',
#  'стоит отметить, что изначально трамп сдержанно отреагировал на критические высказывания британского посла.',
#  'он лишь заявил, что дэррок плохо справляется со своими обязанностями и сша не являются «большими фанатами» посла.',
#  '«мы больше не будем иметь с ним дело», — подчеркнул трамп.',
#  'однако через некоторое время американский лидер обрушился с критикой на дэррока в твиттере.',
#  'трамп назвал британского дипломата «чокнутым» и усомнился в его умственных способностях.',
#  '«это не тот человек, которому рады, он тупой парень.',
#  'я не знаком лично с послом, но мне говорили, что он чванливый глупец», — заявил президент сша.',
#  'инцидент с британским послом не первый, когда дипломаты невысоко оценивают трампа.',
#  'брюссель со своей стороны отказался от новых переговоров и назначил крайний срок выхода лондона из состава ес на 31 октября.',
#  'стоит напомнить, что великобритания также лишится своего посла в москве.',
#  'британский дипломат лори бристоу пообещал покинуть свой пост в 2019 году.',
#  'при этом посол не назвал точную дату своей отставку.',
#  '«сейчас еще рано подводить итоги моей работы», — подытожил бристоу.',
#  'пьяная драка в саратове закончилась гибелью 27-летнего жителя города.',
#  'как сообщает местное издание «свободные новости», конфликт разгорелся в ночь с пятницы на субботу, 15 июня.',
#  'началась перебранка, молодой человек облил девушку пивом.',
#  'после этого стороны конфликта переместились на улицу.',
#  'возле магазина девушки и мужчина продолжили переругиваться, и вскоре началась пьяная драка.',
#  'одна из саратовчанок ударила молодого человека ножом в спину.',
#  'на помощь пришли его друзья — они успели отвезти раненого в больницу.',
#  'врачи провели срочную операцию, но мужчина скончался.',
#  'нож повредил ему правое легкое.',
#  'наказание по этой статье составляет до 10 лет лишения свободы.',
#  'всю компанию дебоширок задержали на соседней улице сотрудники росгвардии.',
#  '«следователи дадут юридическую оценку действиям всех участниц конфликта.',
#  'расследование продолжается», — отметили в следственном управлении скр по саратовской области.',
#  '28-летний мужчина навестил свою 29-летнюю знакомую, находящуюся на 30-й неделе беременности.',
#  'за распитием крепких спиртных напитков приятель сделал ей непристойное предложение, что привело ее в бешенство.',
#  'будущая мать схватила нож и ударила им своего знакомого в грудь, он скончался на месте.',
#  'женщину привлекали ранее к уголовной ответственности, но она была освобождена от наказания по амнистии.',
#  'жуткая история произошла в подмосковье в июне 2018 года.',
#  'пьяная 28-летняя жительница тверской области убила пенсионера в волоколамске, а после попыталась скормить его тело свиньям.',
#  'в результате полученных травм мужчина скончался на месте.',
#  'стремясь скрыть следы убийства, девушка отрубила мертвому пенсионеру голову и бросила ее на съедение свиньям.',
#  'убийцу задержали, было возбуждено уголовное дело.',
#  'в конце мая в ходе ссоры женщина ударила мужчину ножом в шею так сильно, что сломала ему позвонки — смерть наступила мгновенно.',
#  'неделю она продолжала распивать спиртное, а труп продолжал лежать на кровати.',
#  'когда в квартире стало нечем дышать из-за запаха разложения, женщина завернула труп в занавески и спрятала его в подвале.',
#  'тем временем родственники жертвы заявили в правоохранительные органы о его пропаже.',
#  'через 11 дней после исчезновения мужчины полицейские обнаружили его тело в подвале дома.',
#  'женщину задержали и возбудили против нее уголовное дело по части 1 статьи 105 ук рф «убийство».',
#  'вопрос возвращения россии полномочий в парламентской ассамблее совета европы вызвал разногласия среди участников.',
#  'как сообщает rt, большинство стран-участниц пасе поддержали восстановление прав россии в организации.',
#  'единогласно «против» восстановления россии в правах в пасе выступили украина, грузия, эстония, латвия и литва.',
#  'большая часть депутатов делегаций из великобритании, швеции и польши также против того, чтобы россия вернулась в ассамблею.',
#  'не определились с тем, как проголосовать, парламентские делегации лихтенштейна, словении, румынии, финляндии и дании.',
#  'ранее во вторник украинские и грузинские депутаты оспорили полномочия российской делегации.',
#  '25 июня делегация украины покинула зал заседаний пасе.',
#  'об этом сообщил парламентарий от украины алексей гончаренко, передает нсн.',
#  'глава мид украины павел климкин заявил, что совет европы потерял доверие киева, восстановить которое будет чрезвычайно сложно.',
#  '«с лидера усилий для защиты прав человека организация превратилась в простого менеджера, причем такого себе», — заявил он.',
#  'в результате киев отозвал посла при совете европы из-за решения пасе о восстановлении полномочий россии.',
#  'в своем фейсбуке захарова написала, что после стоит консультироваться не с киевом, а сразу с вашингтоном.',
#  '«хотя там могут и наподдать — не столько за провал, сколько за цирк во время провала», — добавила она.',
#  'захарова отметила, что «спецоперация по недопущению россии в пасе готовилась тщательно».',
#  'ранее пасе пригласила участвовать россию в июньской сессии после пятилетнего перерыва.',
#  'резолюция была принята в ночь на 25 июня.',
#  'за нее высказались 118 из 190 членов ассамблеи, 62 были против, 10 воздержались.',
#  'сообщается, что возможность оспаривания полномочий россии сохраняется.',
#  'врачи из университета юты поставили предварительный диагноз нескольким вейперам, пострадавшим от загадочной болезни.',
#  'специалисты выяснили, что у них, вероятно, развилась необычная форма липоидной пневмонии.',
#  'отчет о работе был опубликован в журнале new england journal of medicine.',
#  'липоидная пневмония — редкое заболевание, которое возникает, если в легкие попадает маслянистая жидкость.',
#  'ее симптомы похожи на те, с которыми столкнулись вейперы — одышка, кашель, боль в груди.',
#  'у пациентов же ничего подобного не обнаружилось.',
#  '«если связанное с вейпингом поражение легких — это форма липоидной пневмонии, то это что-то новое, — отмечают врачи.',
#  '— здесь воспаление легких не ограничивается конкретной областью и продолжается довольно долго».',
#  'истории пациентов похожи и весьма печальны.',
#  'так, 18-летний адам из иллинойса столкнулся с болезнью после полутора лет использования вейпа.',
#  'сейчас его легкие — как у семидесятилетнего старика, говорят врачи.',
#  'юноша занимался борьбой, но, если его организм не восстановится, он никогда не вернется к любимому занятию.',
#  'болезнь развилась постепенно.',
#  'врачи сначала не связали симптомы с вейпингом.',
#  'лишь после отсутствия улучшения и посещения нескольких врачей один из них спросил, пользуется ли адам электронным испарителем.',
#  'рентгенограмма показала обширное поражение легких.',
#  '«страшно думать о том, что это маленькое устройство сделало с моими легкими, — говорит адам.',
#  '— если бы я знал, что со мной такое произойдет, никогда бы к нему не притронулся».',
#  'выводы были сделаны на основе шести случаев болезни в штате юта.',
#  'исследователи подробно описали один из них.',
#  'тем временем анализы показали, что пневмококков у юноши нет, но повышен уровень с-реактивного белка, маркера воспаления.',
#  'но наиболее значимой находкой стало обилие макрофагов в биоматериале, полученном из легких.',
#  'макрофаги — это клетки, которые занимаются захватом и перевариванием чужеродных для организма частиц.',
#  'они играют роль первой линии иммунной защиты от патогенов в организме.',
#  'в макрофагах исследователи обнаружили следы жира, который те уничтожали.',
#  'они встречались у всех шестерых пациентов.',
#  'более того, другая группа ученых, обследовав 14 пациентов из висконсина и иллинойса, нашла у них такие же макрофаги.',
#  '«это заставило нас задуматься — зачем они там?',
#  'они собирают вредные вещества, попавшие в легкие во время парения?» — рассказывают исследователи.',
#  'ацетат витамина е содержится в некоторых компонентах, использующихся для сгущения жидкостей.',
#  'эти компоненты популярны в том числе и на черном рынке — их покупают для производства жидкостей с каннабиоидами.',
#  'переваривающие жир макрофаги подтверждают эту версию.',
#  'об эпидемии неизвестного заболевания высказался президент сша дональд трамп.',
#  '«мы не можем позволить людям болеть, мы не можем допустить, чтобы наша молодежь так пострадала, — заявил он.',
#  '— люди умирают от вейпинга».',
#  '— молодежь увлечена электронными сигаретами, это затрагивает детей, семьи, школы.',
#  'отрицательно высказываются о жидкостях для вейпов и другие политики.',
#  '— они предназначены для привлечения детей, и, к сожалению, справляются с этой задачей.',
#  'дети становятся мишенью производителей, и пришло время положить этому конец».',
#  'первые шаги к запрету вейпов сделал штат мичиган.',
#  'в начале сентября 2019 года там было запрещено использование большинства ароматизированных жидкостей для электронных сигарет.',
#  'запрет касается продуктов, в которых используются сладкие и фруктовые ароматы, а также мята и ментол.',
#  'он не распространяется на электронные сигареты со вкусом табака.',
#  'губернатор мичигана гретхен уитмер выразила надежду, что эта мера оградит молодое поколение от вредного воздействия вейпов.',
#  'впоследствии он станет ключевой фигурой белого движения в киеве и будет убит петлюровцами выстрелом в спину.',
#  'ранним утром 21 августа 1914 года русские разъезды засекли сосредоточение австрийцев.',
#  'ввиду приближения неприятеля, келлеру нужно было выиграть время для подтягивания основных войск.',
#  'генерал келлер вместе со своим штабом и конвоем ехал в голове колонны сразу за боевыми разведчиками.',
#  'сражение стартовало с атаки русских конников.',
#  'их полки выстроили фронт и вышли галопом в одну линию.',
#  'драгуны и уланы наступали справа от холма, где был расположен штаб келлера, гусары — слева.',
#  'русские начали спуск в лощину под огнем австрийских пулеметов, которые не смогли сдержать наступавших.',
#  'далее началась беспощадная сеча, в которой рубились с обеих сторон более 2500 всадников.',
#  'атака австрийцев получилась настолько мощной, что русские драгуны и уланы начали сдавать.',
#  '«в этот критический момент граф келлер бросил на весы победы и поражения последнюю, остававшуюся в его руках, маленькую гирю.',
#  '— штаб и конвой как бы ждали это приказание и с места понеслись во фланг проходившему мимо нас эскадрону.',
#  'начальник конвоя сотник цензин, скакавший рядом со мной, выхватил из кобуры револьвер, прицелился и выстрелил.',
#  'несшийся впереди австрийского эскадрона командир его — польский граф — замертво свалился с лошади, сраженный его пулей.',
#  'эскадрон не выдержал нашей атаки; исполнив заезд «по-взводно налево», он стал быстро уходить с поля сражения на север.',
#  'за ним потянулись беспорядочные группы всадников.',
#  'день битвы совпал с полным солнечным затмением.',
#  'солнце покрывалось полупрозрачным диском, окаймленным серебряным сиянием.',
#  'наступало полное затмение солнца.',
#  'генерал келлер с небольшой группой штаба, собравшегося возле него после атаки, поскакал через лощину.',
#  'было около 12 часов дня», — отмечал сливинский.',
#  'сам генерал скончался в эмиграции после второй мировой войны.',
#  '«отрезанные от переправы, австрийцы метались в разные стороны.',
#  'началось ужасное избиение, — штабист сливинский весьма атмосферно описал происходившее после боя.',
#  '— кто мог, спасался конным или пешим через реку вброд.',
#  'груды трупов валялись у самой переправы, занятой казаками.',
#  'все, что доскакало до переправы, погибло под ударами шашек или пик, или сраженное пулей.',
#  'по полю носились во все стороны обезумевшие от страха и потерявшие всадников, кони.',
#  'здесь и там стояли группы пленных.',
#  'между ними, но значительно реже попадались cеpo-желтые пятна — тела погибших и раненых русских».',
#  'потери австрийцев составили 969 всадников убитыми и ранеными.',
#  'еще 250 кавалеристов и 400 пехотинцев сдались в плен.',
#  'в качестве трофеев дивизия келлера захватила 300 лошадей, восемь орудий, пулеметы, боезапас и штабные документы.',
#  'разгром австро-венгров 10-й кавалерийской дивизией стал одним из наиболее громких успехов русской армии на ранней стадии войны.',
#  'однако, как констатировали военные историки, штаб 3-й армии не сумел использовать триумф келлеровцев в должной мере.',
#  'один из своих козырей – сильную и обученную кавалерию – русские войска больше не задействовали, как могли бы.',
#  'в петроград и москву весть о победе в бою у ярославиц пришла время спустя.',
#  'на пути было затмение солнца».',
#  '«постепенно смеркалось.',
#  'за темной тенью скрывался диск солнца.',
#  'освещение окружающего ландшафта быстро приобретало какой-то странный, неземной оттенок, вселяя чувство тревоги.',
#  'как-то совсем внезапно засветилась солнечная корона.',
#  'одновременно кругом по всему горизонту вспыхнула заря.',
#  'продолжалось это странное освещение считанные минуты.',
#  'а отец смотрел, зарисовывал, запоминал, быстро наносил краски на полотно», — рассказывал позднее васнецов-младший.',
#  'об этом сообщает телеграм-канал mash.',
#  'теперь у скандальной пары есть приемные сын и дочь, которым три и два года, — и еще один малыш, рожденный суррогатной матерью.',
#  'примечательно, что все дети будут носить фамилию матери, а не отца.',
#  'регистрация младшего ребенка была сопряжена для пары с серьезными трудностями.',
#  'евгения васильева на тот момент в официальном браке не состояла.',
#  'по этой причине бывшей чиновнице пришлось обратиться в мещанский суд москвы.',
#  'об этом ранее сообщала пресс-секретарь мещанского районного суда юлия бочарова.',
#  'детали иска она не уточнила, объяснив, что эта информация касается частной жизни бывшей чиновницы.',
#  'адвокат васильевой хасан-али бороков , в свою очередь, эту информацию комментировать отказался.',
#  'о роскошной свадьбе васильевой и сердюкова сми сообщали в июле прошлого года.',
#  'малахов рассказал, как забыл в ее 13-комнатной квартире в молочном переулке «коричневый галстук от тома форда ».',
#  '«так что, если анатолий эдуардович увидит среди сумок chanel мужской галстук, пусть не беспокоится», — добавил малахов.',
#  'суд над евгенией васильевой длился 10 месяцев.',
#  'после освобождения васильева поступила в магистратуру факультета искусств мгу и занялась ювелирным бизнесом.',
#  'при этом доля теневого и неформального производства в ввп снижается.',
#  'таким образом, несмотря на сокращение доли в ввп, абсолютные объемы неучтенной экономики с годами увеличиваются.',
#  'сектор, который больше других находится в тени, — это недвижимость.',
#  'неформальная экономика здесь занимает 6,3% ввп, или половину всей серой экономики страны.',
#  'наконец, 0,9% ввп составляет серая экономика строительства.',
#  'к тому же, «белая» экономика почти не предлагает работу с высокой оплатой труда.',
#  'в 2018 году росфинмониторинг оценил объем теневой экономики россии в 20 трлн рублей или 20% ввп страны.',
#  'в 2017 году, по данным ведомства, эта цифра была еще больше — 20,5% ввп.',
#  'в подсчеты включены серый импорт, сокрытие доходов от уплаты налоговых и таможенных платежей и выплата серых зарплат.',
#  'не платят или почти не платят налоги граждане в той части экономики, которая составляет порядка 15-21%.',
#  '«по некоторым, в том числе косвенным, данным, в неформальном секторе трудится порядка 15 млн человек», — заявила она.',
#  'хотя рассмотрение инициативы в такой формулировке в мэр позднее опровергли.',
#  'объем «серых» зарплат в россии за 2018 год составил 13 трлн рублей – 12,6% ввп.',
#  'по данным росстата, это минимальный показатель за последние пять лет.',
#  'по данным ведомства, каждый третий россиянин получал зарплату «в конверте» в прошлом году.',
#  'бороться с теневым сектором призван проект по самозанятым.',
#  'речь идет о специальном налоговом режиме для тех, кто работает на себя.',
#  'эксперимент проводят в москве, московской и калужской областях, а также в татарстане.',
#  '«мы знаем их имена — максим и анания, — отметила исследовательница.',
#  '— максим распоряжается, чтобы анания взял трех лошадей разной масти и вместе с седлами быстро доставил их к нему.',
#  'куда именно, не сказано.',
#  'возможно, появится дополнительная информация, когда будет уточнено время, к которому относится находка».',
#  'торопова подчеркнула, что текст еще предстоит правильно истолковать.',
#  'эксперты отметили достаточно хорошее состояние находки.',
#  'она стала 51-й по счету, найденной на территории этого города.',
#  'археологи продолжают работу на раскопе.',
#  'среди прочего им попадаются и элементы наследия более поздних эпох.',
#  'некоторые находки, по его словам, очень сложно идентифицировать.',
#  '«вот, например, такой деревянный предмет xiii века с пятницкого раскопа в старой руссе.',
#  'довольно сложная, тщательно изготовленная деталь с несколькими отверстиями.',
#  'это явно часть чего-то более сложного, но назначение непонятно.',
#  'есть одно предположение, но пока раскрывать не буду», — отметил колосницын.',
#  'чуть ранее, 10 июля, этот археолог нашел юбилейную, 50-ю берестяную грамоту в старой руссе.',
#  '«18 лет их находили на других раскопах, их находили рядом со мной, их находили на раскопе, которым я руководил.',
#  'а сегодня я, наконец, сам нашел берестяную грамоту.',
#  'сел в конце дня проверять помытую бересту из ящиков в который складывают массовый материал из квадратов.',
#  'на четвертом подносе достаю небольшой сверточек и вижу на нем буквы», — рассказал колосницын.',
#  'археологические работы по поиску записей на коре березы стартовали после великой отечественной войны.',
#  'грамота, найденная археологом бариновым , стала 1227-й за 68 лет на приблизительных землях древней руси.',
#  'больше всего грамот было найдено в новгороде – 1116 – и старой руссе — 51.',
#  'в москве в руки археологов к настоящему моменту попали четыре грамоты, в звенигороде львовской области украины – три.',
#  'столько же обнаружено на территории современной восточной белоруссии.',
#  'знаменитым исследователем языка берестяных грамот являлся выдающийся лингвист андрей зализняк.',
#  'однако у всего есть предел, и, кажется, свое дно сергей шнуров пробил.',
#  '«в клипах сегодня много такого, что нельзя показывать детям.',
#  'что меня возмутило?',
#  'то, что в клипе присутствует сцена употребления наркотиков.',
#  'проституция», — пояснил мильвит риа «восток-медиа».',
#  'мужчина также подчеркнул, что сам является верующим человеком, крестил своих детей и посещает церковь в праздничные дни.',
#  '«я не имею претензий к самому шнуру, некоторые песни я и сам люблю петь, но я считаю, что в этом клипе он переборщил.',
#  'я бы конечно не написал бы и не пожаловался на старое его творчество.',
#  'меня как обывателя, музыканта и общественника возмутило.',
#  'много я слушал и «сектор газа», и «красную плесень», но вот это меня возмутило», — признался он.',
#  '«уважаемые и не очень комментаторы запутались в своих сумбурных желаниях.',
#  'однако история с детьми во владивостоке и клипом шнура — это две большие разницы.',
#  'активист подчеркнул, что выступает за решение любых конфликтов в рамках закона.',
#  'однако они не должны попадать под статью об экстремизме», — добавил он.',
#  'по словам музыканта, он «категорически не согласен» со стерлиговым ситуации с выпускным во владивостоке.',
#  'в подмосковном поселке поварово застрелен директор торгового центра «все», 60-летний николай леонов.',
#  'об этом сообщил риа «новости» источник в правоохранительных органах.',
#  'по данным собеседника агентства, днем 4 июня леонов приехал на работу и вошел в торговый центр со служебного входа.',
#  'когда мужчина подошел к подсобному помещению, за ним проследовал злоумышленник в шлеме мотоциклиста.',
#  'после он три раза выстрелил в директора тц — в том числе в голову.',
#  'убедившись, что жертва скончалась, киллер скрылся с места происшествия.',
#  'следственный комитет опубликовал видео, на котором запечатен момент убийства.',
#  'на кадрах стрелок в шлеме подбегает к двери помещения, стреляет, а затем скрывается с места происшествия на мотоцикле.',
#  'прибывшие следователи и оперативники установили, что стрелял убийца из пистолета макарова с глушителем.',
#  'на месте изъяты три гильзы.',
#  'предполагаемого убийцу задержать пока не удалось.',
#  'следователи не исключают, что убийство могло быть заказным, пишет «коммерсант».',
#  'около 7.00 неизвестный выстрелил в женщину, когда та выходила из подъезда.',
#  'тело шишкиной обнаружил ее муж. оно лежало рядом с ее автомобилем lexus rx270.',
#  'выяснилось, что это не первое покушение.',
#  'в январе 2018 года неизвестные сожгли автомобиль шишкиной — тогда ей удалось спастись.',
#  'она закрылась дома и ждала прибытия полицейских.',
#  'согласно основной версии, убийство шишкиной было заказным.',
#  'главными подозреваемыми стали члены хакерской опг, расследованием преступлений которых занималась следователь.',
#  'на допросе злоумышленник признал свою вину в совершении киберпреступления, однако причастность к убийству шишкиной не признает.',
#  'в ходе допроса абдулазизов рассказал, что его 17-летний сосед по двору в санкт-петербурге пользовался теневым интернетом.',
#  'на одном из форумов ему написал пользователь мигель и предложил за один миллион рублей расправиться со следовательницей.',
#  'молодой человек согласился — более того, в то время он играл в компьютерную игру hitman и выполнял там заказы в роли киллера.',
#  'получив координаты старшего следователя, он выехал в подмосковье и арендовал жилье недалеко от дома убитой.',
#  'в местном лесу он обнаружил пистолет и 30 патронов, которые для него оставил заказчик.',
#  'в день убийства он спрятался в подъезде дома шишкиной.',
#  'когда жертва подошла к стоянке, молодой человек три раза выстрелил в нее.',
#  'еще одна трагедия 2 сентября 2018 года произошла в москве.',
#  'тогда на станции метро «курская» кольцевой линии был убит полицейский 4-го отдела увд андрей райский.',
#  'незадолго до чп силовик задержал мужчину для проверки документов.',
#  'по данным силовиков, во время разговора задержанный отпросился в туалет — полицейский его сопроводил.',
#  'затем, по словам уборщицы, в помещении раздался хлопок.',
#  'впоследствии там обнаружили правоохранителя с огнестрельным ранением в голову.',
#  'подозреваемым в убийстве стал 42-летний нурлан муратов, утром того же дня он был задержан на станции метро «павелецкая».',
#  'ему предъявили обвинение по статье 317 ук рф «посягательство на жизнь сотрудника правоохранительных органов».',
#  'от рук убийцы погибли 22 человека в возрасте от 2 до 83 лет.',
#  'еще 25 человек получили ранения различной степени тяжести.',
#  'однако против визита трампа резко выступили демократы.',
#  '«президент, который способствовал ненависти, сделавшей возможной субботнюю трагедию, не должен приезжать в эль-пасо.',
#  'нам не нужно раздоров, нам нужно исцеление.',
#  'ему здесь не место», — заявил накануне экс-конгрессмен от штата техас демократ бето о`рурк.',
#  "о'рурк — давний критик трампа.",
#  'для самого главы белого дома, несмотря на скорбную миссию, в поездке в техас будет немало политики.',
#  'штат «единой звезды» считается столпом республиканской политики.',
#  'губернатором здесь в свое время был джордж буш-младший , впоследствии ставший президентом сша.',
#  'богатый нефтью штат, один из главных локомотивов американской экономики традиционно поддерживает республиканцев.',
#  'в 2016 году трамп со значительным перевесом — в 10% голосов — победил в техасе свою соперницу хиллари клинтон.',
#  'во время публичных выступлений в эль-пасо, если таковые состоятся, трампу не избежать разговора на тему продажи оружия.',
#  'техас — один из самых вооруженных штатов сша.',
#  'его население составляет более 27 млн человек, при этом на руках здесь 22 млн единиц оружия.',
#  'по данным nbc, на днях губернатор штата грег абботт подписал необходимые для этого документы.',
#  'среди подписанных документов — закон, позволяющий носить оружие учителям, чтобы оказать сопротивление нападающими.',
#  'известно, что организация пользуется покровительством трампа.',
#  'заявив, что вторая поправка сегодня «под угрозой», он уверил членов nra, что пока он президент, им не о чем беспокоиться.',
#  'в целом, члены ассоциации в значительной степени поддерживают трампа.',
#  '«они поддержали его на ранней стадии кампании в 2016 году, и с тех пор эта поддержка остается достаточно сильной.',
#  'при этом трамп сразу после расстрелов в техасе и огайо сделал реверанс в сторону противников свободного ношения оружия.',
#  'в москве продолжает бушевать сильный ветер — его скорость достигает 17 м/с.',
#  'в городе объявлен желтый уровень опасности, мчс призывает людей быть внимательными и избегать шатких конструкций.',
#  'низкая температура, вплоть до сентябрьских значений, порывистый ветер сохранятся в столице до конца недели.',
#  'он отметил, что холод, дожди и низкое атмосферное давление сохранятся в москве вплоть до середины июля.',
#  '«я не вижу летнего тепла до середины месяца.',
#  'возможно, тепло вернется после середины июля.',
#  'на этих выходных мы достигнем «холодного дна», потом температура начнет медленно-медленно расти, еле-еле выбираться за +20 °с.',
#  'для июля это достаточно прохладная погода», — уточнил синоптик.',
#  'опасная ситуация, возникшая на улицах москвы в связи с погодными условиями, уже привела к человеческим потерям.',
#  'так, в столичном районе басманный погиб трехлетний ребенок, сообщили в столичном департаменте здравоохранения.',
#  'на мальчика во время прогулки во дворе упало дерево.',
#  'по словам соседей, ребенок и его брат-близнец играли на детской площадке, как вдруг раздался громкий крик.',
#  'местная жительница, которая сразу же выбежала во двор, увидела, как мать пытается вытащить мальчика из-под дерева.',
#  '«я выбежала, у меня просто первый этаж, выскочила.',
#  'два парня, мама пытаются дерево поднять.',
#  'дерево прямо лежит на голове.',
#  'маленький ребенок лежит в песочнице.',
#  'и четко по голове у него», — рассказала горожанка телеканалу «москва 24».',
#  'очевидцы происшествия помогли достать мальчика, однако тот не подавал признаков жизни.',
#  'ребенок скончался от тяжелых травм, несовместимых с жизнью.',
#  'на место чп прибыли медработники, чтобы оказать психологическую помощь матери.',
#  'ее второй ребенок отделался небольшими ссадинами.',
#  'мэр москвы сергей собянин в свою очередь выразил соболезнования семье погибшего ребенка.',
#  '«в москве от урагана погиб ребенок.',
#  'приношу самые глубокие соболезнования семье.',
#  'в эти дни в столице — критические погодные условия.',
#  'прошу обращать особое внимание на предупреждения мчс и городских служб.',
#  'будьте внимательны», — написал он в твиттере.',
#  'это уже не первое чп, произошедшее в результате непогоды.',
#  'в пресс-службе депздрава москвы сообщили, что на неделе в столице госпитализировали четырех человек.',
#  'так, на краснопресненской набережной из-за сильного ветра на мужчину упал дорожный знак.',
#  'пострадал и ребенок, на которого обрушилось дерево — в больнице у него зафиксировали небольшие травмы.',
#  'на севастопольском и пролетарском проспектах из-за падения деревьев также пострадали две женщины.',
#  '«всем медицинская помощь оказывается в полном объеме», — подчеркнули в ведомстве.',
#  'еще один инцидент в четверг, 4 июля, произошел в нагатинском затоне на юго-востоке москвы.',
#  'там спасатели вытащили из воды 32-летнего рыбака, чья лодка перевернулась из-за сильного ветка, пишет «российская газета».',
#  'спасатели помогли москвичу добраться до берега, где его дожидалась бригада медиков.',
#  'череда несчастных случаев, связанных с погодой, обрушилась на москву еще в последние дни июня.',
#  'тогда на юго-востоке города в воронцовском парке москвичка получила травмы от упавшей на нее ветки.',
#  '«в москве плохая погода.',
#  'одна ветка упала на нее, женщина получила травму», — сообщал тасс со ссылкой на префектуру юзао.',
#  'пострадавшую госпитализировали в тяжелом состоянии.',
#  'более 70% россиянок верят, что мужчины могут воспитывать детей и вести домашнее хозяйство не хуже женщин.',
#  'данные социологического опроса публикует на своем сайте всероссийский центр изучения общественного мнения ( вциом ).',
#  '«за последние два года представления россиян о роли отцов в обществе изменились несущественно», – говорится в пресс-релизе.',
#  'среди молодежи от 18 до 24 лет сразу 90% считают, что мужчины способны быть хорошими отцами.',
#  'большинство российских граждан (около 65%) не знают о нетрадиционном распределении родительских ролей у знакомых.',
#  'только каждый 10-й россиянин слышал или знает о подобной ситуации у приятелей.',
#  'между тем 63% женщин выступили против «мужского декрета».',
#  'с ними согласны 55% мужчин – за ребенком, по их мнению, должна ухаживать мать.',
#  'при этом 42% россиян согласились бы ухаживать за детьми вместо супруги.',
#  'мнения разделились при ответе на вопрос: «кто должен быть добытчиком?».',
#  'мужской эту роль назвали около 48%, а 47% не считают, что работа важнее воспитания детей.',
#  'ограничивать общение между отцом и ребенком в случае супружеской размолвки нельзя — так полагают 90% респондентов.',
#  'он также выступил за введение «отцовского капитала» в россии.',
#  '«самой весомой из вновь принятых мер может стать отцовский семейный капитал при рождении третьего и последующих детей в семье.',
#  'ранее вице-премьер татьяна голикова не исключила введения новых мер стимулирования рождаемости в россии.',
#  'в частности, правительство может ввести выплату материнского капитала за первого ребенка в семье.',
#  '«я не буду скрывать, и такие варианты тоже обсуждаются.',
#  'конечно, на это потребуются значительные средства», — признала голикова.',
#  'это связано со многими аспектами — в том числе и с необходимостью обеспечения «сохранения нации», сказала голикова.',
#  'спустя день президент россии владимир путин заявил, что власти обсуждают новые меры господдержки семей с детьми.',
#  'об этом он сказал на церемонии вручения орденов «родительская слава».',
#  'и мы обязательно продолжим эту работу.',
#  'ранее нсн сообщала, что американские ученые выяснили лучший возраст для отцовства.',
#  'они посоветовали мужчинам заводить детей до 40 лет.',
#  'у поздних малышей выше риск развития аутизма или синдрома дауна.',
#  'кроме того, на здоровье ребенка могут сказаться и вредные привычки отца.',
#  'по мнению ученых, алкоголизм у папы может привести к проблемам с вниманием, координацией или к гиперактивности малыша.',
#  'национальный банк грузии отказался поддерживать курс нацвалюты за счет продажи резервов.',
#  'об этом сообщается на сайте регулятора.',
#  'как пояснили в нацбанке, резкое снижение курса выполняет роль нивелирующего шок механизма.',
#  'при этом в тбилиси признали взаимосвязь падения курса лари и проблем в отношениях с россией.',
#  'при этом, по словам регулятора, наличие адекватных валютных резервов обеспечивает экономике стабильность.',
#  'это оказалось максимумом за всю историю существования грузинских денег со времен развала ссср.',
#  'запрет пока не вводится.',
#  '«во время временных курсовых колебаний валюты тратить резервы цб на поддержание национальной валюты — идея весьма сомнительная.',
#  'и чем дольше страна этот процесс откладывает, тем хуже потом в будущем окажутся отложенные на потом последствия.',
#  'при этом впереди у лари, по всей видимости, новые антирекорды.',
#  'так, в ближайшее время курс лари продолжит падать.',
#  'за несколько месяцев курс вполне может достичь и 3,5 лари за доллар, полагает капустянский.',
#  'в ближайшее время грузию ждет рост инфляции, как это было в россии в 2014-2015 годах, предсказывает аналитик.',
#  '«на борту судна 18 индийцев, трое членов экипажа из россии, а также граждане филиппин, латвии и других стран.',
#  'капитан — индиец, но танкер британский», — сказал он.',
# ...
#  '«позор нам.',
#  '«я предложил взять памятник министерству и разместить его на своей территории.',
#  'таким образом, статуя покидает общественное пространство, а также получает защиту от вандалов.',
#  'все будут довольны, не так ли?», — написал он в твиттере.',
#  'на некоторых из них были надеты футболки с символикой ссср.',
#  'люди размахивали российскими и советскими флагами, виднелся и флаг самопровозглашенной донецкой народной республики.',
#  'лидером движения защиты памятника является яна вольфова — председатель чешской партии суверенитета.',
#  'ее представители заявили, что намерены добиваться увольнения колара.',
#  'также на митинге присутствовали депутаты-коммунисты зденек ондрачек и ивана невлудова.',
#  'полиция охраняла вход в здание ратуши.',
#  'стоит отметить, что войска под командованием маршала конева в мае 1945 года выбили немецких нацистов из праги.',
#  'памятник был воздвигнут в 1980 году и уже несколько раз подвергался осквернению, передает нсн.',
#  'сказать в лицо свои претензии они не могут, но памятник ведь ответить не в состоянии.',
#  'поэтому они с ними смелые.',
#  'они хотят быть вассалами у других государств», — пояснил парламентарий.',
#  'несколько лет назад в польском городе пененжно демонтировали бюст генерала ивана черняховского.',
#  'барельеф памятника был передан посольству россии в польше.',
#  'после принятия закона ямпольская доходчиво объяснила, как именно он будет работать.',
#  'так и спрашивают: «вам сколько и на какую дату?» на данный момент эффективных средств борьбы с ними не существует.',
#  'единственной санкцией остается штраф за торговлю в неположенном месте.',
#  'его размер — от 500 до 2500 рублей.',
#  'это комариный укус для людей, чья прибыль составляет десятки и сотни тысяч.',
#  'представители большого театра в разговоре с еленой ямпольской признались, что бессильны против этого явления.',
#  'если перекупщики проникают в фойе, их выводит охрана.',
#  'но территория перед театром принадлежит городу.',
#  'ямпольская не в первый раз напоминает, что наказания за «спекуляцию» в условиях рыночной экономики не существует.',
#  'а дефицит и спекуляция всегда идут рука об руку.',
#  'что же изменится теперь?',
#  '— список всех уполномоченных лиц будет размещен на официальном сайте организации.',
#  '— правительство направило в госдуму пакет законопроектов, — напомнила депутат.',
#  'но в любом случае, сумма окажется гораздо серьезнее, чем 2500 рублей.',
#  'в законе также прописано, что билеты с исправлениями являются недействительными.',
#  'ямпольская рассказала, что в закон введены диспозитивные (разрешительные) нормы для театров, страдающих от перекупщиков.',
#  'прежде всего — право продавать именные билеты.',
#  '— перекупщики все нереализованное норовят незадолго до спектакля сдать в кассу.',
#  'теперь они такой возможности лишаются.',
#  'в этом «бизнесе» возникает слишком много риска, он перестает быть выгодным и, надеемся, начнет отмирать.',
#  'однако, говорит ямпольская, решена только часть проблемы.',
#  '— однако такая форма «спекуляции» уходит в прошлое.',
#  'основная перепродажа ведется в интернете.',
#  'еще раз подчеркну, что принятый закон разрешает торговать билетами только самим и организациям и уполномоченным лицам.',
#  'то есть те, кто продает билеты онлайн без заключения договоров, действуют противозаконно.',
#  'на мой взгляд, есть все основания вводить досудебную блокировку.',
#  'но пока это только предположение.',
#  'депутаты планируют внести его в гд в осеннюю сессию.',
#  'он отметил, что 17 июня врачи проведут алибасову контрольную гастроскопию, передает риа «новости».',
#  '«в понедельник будет контрольная гастроскопия.',
#  'также он рассказал, что, возможно, его отец будет проходить реабилитацию в одном из санаториев казахстана.',
#  '«там в горной местности воздух хороший, ему отдельное шале в горах должны предоставить.',
#  'выбор стоял между германией еще, но в казахстане лечение отнюдь не хуже», — поделился сын продюсера.',
#  'свое решение отправить отца за границу он объяснил тем, что в москве продюсера будет беспокоить большое количество посетителей.',
#  '«и это в реанимацию проникнуть трудно, а что будет в обычной палате, его ж просто достанут», — заключил алибасов-младший.',
#  'на случай экстренной госпитализации имеется вертолетное сообщение», — цитирует его тасс.',
#  'в настоящий момент, напомним, заслуженный артист россии находится в нии имени склифосовского.',
#  'о попадании продюсера в больницу стало известно в начале минувшей недели.',
#  '«папа на студии вместо сока выпил жидкость для очистки труб, перепутал стаканы, сейчас он в больнице», — сообщил он.',
#  '«если все будет хорошо, то выздоровление может занять месяцы», — подчеркнул он.',
#  'к счастью, пробыв в состоянии комы несколько дней, алибасов очнулся: произошло это 11 июня.',
#  'представитель бари тогда, однако, отметил, что продюсер после пробуждения ничего не помнит, а также не может разговаривать.',
#  'кроме того, мужчина не исключил даже вероятность летального исхода.',
#  '«надеюсь, в ближайшее время он придет в себя.',
#  'сказать, что этого риска нет, можно будет только через пару дней», — поведал журналистам горжанкин.',
#  'высказался относительно ситуации в тот день и сын алибасова: «долгожданная новость.',
#  'отец проснулся.',
#  'сейчас это самое главное.',
#  'правда, пока он не может говорить и совершенно ничего не помнит.',
#  'даже то, что он бари алибасов, — полная амнезия.',
#  'конечно, это страшно.',
#  'надеюсь, отец все-таки придет в себя».',
#  'вместе с тем он добавил, что за прошедшее время алибасов серьезно сбавил в весе.',
#  'по словам родственника, у его отца — после выхода из комы — был «мозг пятилетнего ребенка».',
#  '«он скинул, по меньшей мере, 8-9 килограммов, по одному в день.',
#  'но самое страшное, что после пяти суток медикаментозного сна он совсем ничего не помнит и не осознает себя.',
#  'у папы сейчас мозг пятилетнего ребенка», — пояснил он kp.ru.',
#  '— меня, сына, он не признал, а супругу лидию николаевну и вовсе принял за медсестру.',
#  'в какой-то момент отец отобрал у меня телефон, совсем как ребенок, и сделал селфи.',
#  'был этим очень доволен».',
#  'на льду спортсменка появилась в красивом черном кружевном платье.',
#  'она без ошибок выполнила прыжковые элементы, однако не показала ни одного каскада.',
#  'зрители, которые присутствовали на шоу, остались в восторге и встречали почти каждый сделанный элемент аплодисментами.',
#  'пока программу вживую могут оценить только на шоу в японии.',
#  'в россии загитова представит свое выступление только в сентябре – на контрольных прокатах сборной россии.',
#  'мнения российских болельщиков по поводу короткой программы загитовой разделились.',
#  'большая часть поклонников фигуристки осталась в восторге от выступления любимицы.',
#  '«под впечатлением... даже не ожидала, что с первого раза и такой эффект произведет новая программа.',
#  'представляю, какая бомба будет.',
#  'это очень красиво, проникновенно, чувственно!',
#  'однако некоторым любителям фигурного катания прокат не понравился.',
#  'причины для этого были совершенно разнообразные.',
#  'именно поэтому в прокатах становится видно однообразие.',
#  'в минусах новой программы также заметили то, что для алины она тяжеловата в моральном плане.',
#  'также некоторые фанаты не увидели и не поняли смысла и истории в выступлении спортсменки.',
#  '«истории я не увидела.',
#  'программы нет.',
#  'есть алина, шикарное платье, техника, катание и очень странное вытье взрослой женщины.',
#  'а алина вроде молодая, и страдания эти ей только заучивать.',
#  'я бы оставила это для показательных и поставила бы новую короткую программу.',
#  'молодежную, драйвовую, быструю», — высказала мнение одна из поклонниц фигуристки.',
#  'поклонники переживали, что фигуристка мало времени тратит на тренировки и подготовку к новому сезону.',
#  'а спортсменка тем временем делилась кадрами своей жизни.',
#  'на кадрах выложенного видео было видно, как алина делает растяжку в салоне автомобиля.',
#  'также загитова приняла участие в популярном интернет-челлендже bottle cap.',
#  'причем бутылку она открыла дважды – первый раз с помощью лапы своей собаки масару, а во второй – лезвием конька.',
#  'однако в скором времени все вошло в привычное русло, загитова приступила к тренировкам.',
#  '10 июня состоялся суд над полковником мвд дмитрием захарченко , у которого нашли 9 млрд рублей.',
#  'в ходе расследования таинственно исчезли 3 млн евро из этой суммы.',
#  'вину по основному эпизоду суд счел недоказанной.',
#  'и все равно захарченко приговорили к 13 годам колонии и 117 млн рублей штрафа.',
#  'совершенно фантасмагорическая история произошла в сочи.',
#  'по официально версии, цапок умер в сизо еще в 2014 году — от инсульта.',
#  'на фотографиях он ел крабов, икру (не «заморскую, баклажанную») и жарил прямо в колонии шашлык.',
#  'по словам максименко, это якобы «старые» фото, которые относятся к 2015 году.',
#  'тем самым он, во-первых, признал, что кровавый бандит шиковал на зоне по крайней мере четыре года назад.',
#  'по крайней мере краснодарские силовики трогать банду цапка почему-то не решались, хотя знали о ее преступлениях.',
#  'один из преступников пытался поджечь стену, бросив в сторону дома бутылку с зажигательной смесью.',
#  'фабрикация уголовных дел в россии, с большой вероятностью, поставлена на поток.',
#  'громкие преступления самих силовиков тоже не прекращаются.',
#  'в 57 регионах преступлений стало больше, в 28 — меньше.',
#  'почти 40% всех зарегистрированных преступлений — кражи.',
#  'число погибших в результате преступлений сократилось на 1,3%.',
#  'к преступлениям, связанным с наркотиками, благодаря «доблестным полицейским» из «дела гоулнова» сейчас особое внимание.',
#  'аж на 44,6% (с 5 971 до 3 309) сократилось число людей, совершивших преступления в состоянии наркотического опьянения.',
#  '57,2% преступлений совершили рецидивисты — еще один большой привет российской системе исполнения наказаний.',
#  'плачевные.',
#  'во-вторых, доверие россиян к силовым структурам продолжает оставаться крайне низким.',
#  'в-третьих, громких преступлений с участием силовиков — от убийств до взяток в особо крупных размерах — не становится меньше.',
#  'в результате силовики в значительной степени вовлечены как в рутинный процесс бытовых взяток, так и в массу теневых бизнесов.',
#  'российские власти публично говорят о коррупции как об одной из главных проблем общества.',
#  'те, кто по долгу службы стоит на страде закона, не имеют ни юридического, ни морального права нарушать этот закон.',
#  'иначе мы так и будем жить, говоря языком криминального мира, по беспределу.',
#  'поэт встретил февральскую и октябрьскую революции со смешанными чувствами, но отказался от эмиграции.',
#  'в знаменитой поэме «двенадцать» он пытался осмыслить октябрьскую революцию через призму метафор.',
#  'произведение получилось неоднозначным и не смогло раскрыть конкретное отношение блока к происходящему в стране.',
#  '«двенадцать» — ироническая вещь.',
#  'она написана даже не частушечным стилем, она сделана «блатным» стилем.',
#  'стилем уличного куплета вроде савояровских», — отметил шкловский.',
#  'свое состояние того периода он описывал словами «меня выпили».',
#  'тем временем на фоне проблем и трудной жизни в революционном петрограде физическое состояние поэта продолжало ухудшаться.',
#  'у блока была выявлена астма, развились психические расстройства, а зимой 1920 года его поразила цинга.',
#  'для приведения своего здоровья в порядок поэт решил отправиться на лечение в финляндию.',
#  'вместе с коллегой федором сологубом он подал в политбюро запрос на получение выездных виз, но получил отказ.',
#  'его слова процитировали авторы книги «в огне революции» мария спиридоновна и лариса рейснер.',
#  'однако на тот момент состояние поэта стало значительно хуже, и горький вызвался его сопровождать.',
#  'соответствующие документы были подписаны уже через неделю, но писатель узнал об этом только 6 августа.',
#  'за несколько дней до смерти поэт был одержим этой мыслью, бредил и отказывался от воды и пищи.',
#  'вспомнив, что один из экземпляров мог остаться у поэта василия брюсова, блок кричал, что «убьет» коллегу.',
#  'однако те же специалисты недоумевали по поводу быстрой смерти блока, не характерной для этого заболевания.',
#  'они также не могли назначить больному метод лечения и безуспешно пытались использовать морфий для облегчения симптомов.',
#  'по его словам, они поднимали этот вопрос на всех встречах с американскими законодателями.',
#  '«несмотря на то, что президент [сша дональд трамп] делает, конгресс сша с вами», — заверил джонсон.',
#  'рон джонсон входит в так называемый «кокус (объединение законодателей по интересам — «газета.ru») по украине».',
#  'послание было адресовано директору административно-бюджетного управления белого дома мику малвэни.',
#  'текст письма разместили на сайте портмана.',
#  'в нем сенаторы назвали это финансирование «критически важным для обеспечения долгосрочной жизнеспособности украинских военных».',
#  'по данным телекомпании, президент сша неоднократно говорил о возможности пойти на такой шаг.',
#  'в пентагоне обратили внимание, что с 2014 года вашингтон уже предоставил киеву $1,5 млрд в качестве военной помощи.',
#  'если финансирование все же будет утверждено в таком объеме, украина получит на $50 млн больше, чем в текущем году.',
#  'предполагается, что именно такая сумма будет потрачена на летальное оружие, призванное повысить обороноспособность страны.',
#  'правда, соглашение, каким бы выгодным оно не казалось, не заменит лондону евросоюз.',
#  'согласно статистике, на страны ес приходится 49% торговли королевства, тогда как на сша — всего 15%.',
#  'при этом известно, что американский президент давал понять, что был рад выходу великобритании из ес.',
#  'многие из ее выводов до сих пор не устарели.',
#  'в докладе утверждается, что лондон вполне мог отказать сша в сотрудничестве по ираку.',
#  'поклонником черчилля является и главный фаворит трампа в борьбе за лидерство в консервативной партии — борис джонсон.',
#  'экс-глава мид великобритании в прошлом — гражданин сша, и неоднократно источал комплименты в адрес трампа.',
#  'от укрепления британо-американского союза косвенно может пострадать и россия.',
#  'отношения москвы и лондона давно складываются не лучшим образом и стали практически враждебными после «дела скрипаля ».',
#  'даже уходя со своего поста, мэй вновь упомянула о «российской угрозе» в присутствии трампа.',
#  'разведки обеих стран и без того взаимодействуют теснейшим образом, что проявилось даже во время предвыборной кампании в сша.',
#  'причем, по данным, el universal, стороны уже вступили в переговоры и очень близки к заключению соглашения!',
#  '«мы в процессе переговоров.',
#  'думаю, в ближайшее время все все узнают.',
#  'мне бы не хотелось уходить, но сейчас не все зависит от меня.',
#  'мы еще в ноябре начали переговоры, но на данный момент новое соглашение не подписано.',
#  'за 11 лет мы не раз продлевали контракт с цска, и проблем со мной никогда не было, — рассказывал тогда дзагоев.',
#  '— у меня нет агента, я всегда был открыт для переговоров.',
#  'мы каждый раз находили точки соприкосновения и приходили к общему решению.',
#  'роман юрьевич бабаев с этим согласился.',
#  'я хочу остаться в цска.',
#  'нам с клубом нужно найти взаимопонимание.',
#  'если это произойдет, я останусь и буду счастлив.',
#  'я с 15 лет, с победы цска в кубке уефа , душой и сердцем с этим клубом.',
#  'болел за него, уже 11 лет отыграл как футболист.',
#  'естественно, это не чужая мне команда – все родное.',
#  'я не раз говорил, что хочу всю карьеру провести в цска.',
#  'я всегда всего себя отдавал этому клубу и готов отдавать дальше».',
#  'если алан перейдет в «тигрес», он станет первым в истории российским легионером в чемпионате мексики.',
#  '«я хочу вызвать тома круза на бой на ринге.',
#  'том, если ты не примешь этот бой — ты испугался и никогда этого не переживешь.',
#  'кто хочет организовать бой?» — спросил бибер, отметив в сообщении действующего президента ufc дану уайта.',
#  'i wanna challenge tom cruise to fight in the octagon.',
#  'tom if you dont take this fight your scared and you will never live it down.',
#  'who is willing to put on the fight?',
#  ...]

# %%
chars = Counter()

for sentence in tqdm(sentences):
    for char in sentence:
        chars[char] += 1
# Out:
#   0%|          | 0/122237 [00:00<?, ?it/s]

# %%
print(len(chars))
# Out:
# 132

# %%
vocab = set(['<unk>', '<bos>', '<eos>', '<pad>'])
counter_threshold = 500

for char, cnt in chars.items():
    if cnt > counter_threshold:
        vocab.add(char)

# %%
len(vocab)
# Out:
# 86

# %%
char2ind = {char: i for i, char in enumerate(vocab)}
ind2char = {i: char for char, i in char2ind.items()}

# %%
char2ind.get('€','€ is not found')
# Out:
# '€ is not found'

# %%
class CharDataset:
    def __init__(self, sentences):
        self.data = sentences
        self.unk_id = char2ind['<unk>']
        self.bos_id = char2ind['<bos>']
        self.eos_id = char2ind['<eos>']
        self.pad_id = char2ind['<pad>']

    def __getitem__(self, idx: int) -> List[int]:
        tokenized_sentence = [self.bos_id]
        tokenized_sentence += [char2ind.get(char, self.unk_id) for char in self.data[idx]]
        tokenized_sentence += [self.eos_id]

        return tokenized_sentence

    def __len__(self) -> int:
        return len(self.data)

# %%
def collate_fn_with_padding(
    input_batch: List[List[int]], pad_id=char2ind['<pad>']) -> torch.Tensor:
    seq_lens = [len(x) for x in input_batch]
    max_seq_len = max(seq_lens)

    new_batch = []
    for sequence in input_batch:
        for _ in range(max_seq_len - len(sequence)):
            sequence.append(pad_id)
        new_batch.append(sequence)

    sequences = torch.LongTensor(new_batch).to(device)

    new_batch = {
        'input_ids': sequences[:,:-1],
        'target_ids': sequences[:,1:]
    }

    return new_batch

# %%
train_sentences, eval_sentences = train_test_split(sentences, test_size=0.2)

train_dataset = CharDataset(train_sentences)
eval_dataset = CharDataset(eval_sentences)

train_dataloader = DataLoader(
    train_dataset, collate_fn=collate_fn_with_padding, batch_size=256)

eval_dataloader = DataLoader(
    eval_dataset, collate_fn=collate_fn_with_padding, batch_size=256)

# %%
print(train_dataset[0])
print(list(map(ind2char.get, train_dataset[0])))
# Out:
# [80, 38, 64, 7, 4, 55, 7, 38, 4, 58, 47, 22, 4, 28, 65]
# ['<bos>', 'в', 'ы', ' ', 'и', 'х', ' ', 'в', 'и', 'д', 'е', 'л', 'и', '?', '<eos>']

# %% [markdown]
# ## Архитектура модели

# %%
class CharLM(nn.Module):
    def __init__(self, hidden_dim: int, vocab_size: int):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, hidden_dim)
        self.rnn = nn.GRU(hidden_dim, hidden_dim, batch_first=True)
        self.linear = nn.Linear(hidden_dim, hidden_dim)
        self.projection = nn.Linear(hidden_dim, vocab_size)

        self.non_lin = nn.Tanh()
        self.dropout = nn.Dropout(p=0.1)

    def forward(self, input_batch) -> torch.Tensor:
        embeddings = self.embedding(input_batch)  # [batch_size, seq_len, hidden_dim]
        output, _ = self.rnn(embeddings)  # [batch_size, seq_len, hidden_dim]
        output = self.dropout(self.linear(self.non_lin(output)))  # [batch_size, seq_len, hidden_dim]
        projection = self.projection(self.non_lin(output))  # [batch_size, seq_len, vocab_size]

        return projection

# %% [markdown]
# ## Train loop

# %%
def evaluate(model, criterion) -> float:
    """
    Calculate perplexity on validation dataloader.
    """

    model.eval()
    perplexity = []
    with torch.no_grad():
        for batch in eval_dataloader:
            logits = model(batch['input_ids']).flatten(start_dim=0, end_dim=1)
            loss = criterion(
                logits,
                batch['target_ids'].flatten()
                )
            perplexity.append(torch.exp(loss).item())

    perplexity = sum(perplexity) / len(perplexity)

    return perplexity

# %%
model = CharLM(hidden_dim=256, vocab_size=len(vocab)).to(device)
criterion = nn.CrossEntropyLoss(ignore_index=char2ind['<pad>'])
optimizer = torch.optim.Adam(model.parameters())

# %%
num_epoch = 10
losses = []
perplexities = []

for epoch in range(num_epoch):
    epoch_losses = []
    model.train()
    for batch in tqdm(train_dataloader, desc=f'Training epoch {epoch}:'):
        optimizer.zero_grad()
        logits = model(batch['input_ids']).flatten(start_dim=0, end_dim=1)
        loss = criterion(
            logits, batch['target_ids'].flatten())
        loss.backward()
        optimizer.step()

        epoch_losses.append(loss.item())

    losses.append(sum(epoch_losses) / len(epoch_losses))
    perplexities.append(evaluate(model, criterion))
# Out:
# Training epoch 0::   0%|          | 0/382 [00:00<?, ?it/s]
# Training epoch 1::   0%|          | 0/382 [00:00<?, ?it/s]
# Training epoch 2::   0%|          | 0/382 [00:00<?, ?it/s]
# Training epoch 3::   0%|          | 0/382 [00:00<?, ?it/s]
# Training epoch 4::   0%|          | 0/382 [00:00<?, ?it/s]
# Training epoch 5::   0%|          | 0/382 [00:00<?, ?it/s]
# Training epoch 6::   0%|          | 0/382 [00:00<?, ?it/s]
# Training epoch 7::   0%|          | 0/382 [00:00<?, ?it/s]
# Training epoch 8::   0%|          | 0/382 [00:00<?, ?it/s]
# Training epoch 9::   0%|          | 0/382 [00:00<?, ?it/s]

# %%
plt.plot(np.arange(len(losses)), losses)
plt.title('Losses')
plt.xlabel("epoch")
plt.show()

# %%
plt.plot(np.arange(len(perplexities)), perplexities)
plt.title('Perplexity')
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# ## Generation

# %%
def generate_sequence(model, starting_seq: str, max_seq_len: int = 128) -> str:
    device = 'cpu'
    model = model.to(device)
    input_ids = [char2ind['<bos>']] + [
        char2ind.get(char, char2ind['<unk>']) for char in starting_seq]
    input_ids = torch.LongTensor(input_ids).to(device)

    model.eval()
    with torch.no_grad():
        for i in range(max_seq_len):
            next_char_distribution = model(input_ids)[-1]
            next_char = next_char_distribution.squeeze().argmax()
            input_ids = torch.cat([input_ids, next_char.unsqueeze(0)])

            if next_char.item() == char2ind['<eos>']:
                break

    words = ''.join([ind2char[idx.item()] for idx in input_ids])

    return words

# %%
generate_sequence(model, starting_seq='по системе гол плюс пас ')
# Out:
# '<bos>по системе гол плюс пас политик получил президент сша и получил политика.<eos>'

# %%
result = '<bos>по системе гол плюс пас произошло в своем телеканале «российский процесс в столице собственности в стране на противоречивом в состоянии в состоянии в со'

# %%
len(result.split(' '))
# Out:
# 24
